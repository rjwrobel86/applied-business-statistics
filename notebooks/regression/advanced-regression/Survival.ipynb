# %% [markdown]
# # Survival Analysis
# ## Used to model time until an event occurs

# %%
from lifelines import CoxPHFitter
from lifelines.datasets import load_rossi
import matplotlib.pyplot as plt

# %%
#Rossi recidivism data
df = load_rossi()
df.head()
x_vars = ['arrest','fin','age','race','wexp','mar','paro','prio']
X = df[x_vars]

# %%
#Cox Proportional Hazards model
cph_model = CoxPHFitter()
results = cph_model.fit(df, duration_col='week', event_col='arrest')
results.summary
# Out:
#                coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# covariate
# fin       -0.379422   0.684257  0.191379       -0.754519       -0.004325
# age       -0.057438   0.944181  0.021999       -0.100556       -0.014320
# race       0.313900   1.368753  0.307993       -0.289755        0.917555
# wexp      -0.149796   0.860884  0.212224       -0.565748        0.266156
# mar       -0.433704   0.648104  0.381868       -1.182152        0.314744
# paro      -0.084871   0.918631  0.195757       -0.468547        0.298805
# prio       0.091497   1.095814  0.028649        0.035347        0.147647
#
#            exp(coef) lower 95%  exp(coef) upper 95%  cmp to         z  \
# covariate
# fin                   0.470237             0.995684     0.0 -1.982565
# age                   0.904335             0.985782     0.0 -2.610869
# race                  0.748447             2.503162     0.0  1.019179
# wexp                  0.567935             1.304939     0.0 -0.705837
# mar                   0.306618             1.369908     0.0 -1.135743
# paro                  0.625911             1.348247     0.0 -0.433554
# prio                  1.035979             1.159104     0.0  3.193777
#
#                   p  -log2(p)
# covariate
# fin        0.047416  4.398479
# age        0.009031  6.790860
# race       0.308118  1.698445
# wexp       0.480290  1.058023
# mar        0.256064  1.965422
# paro       0.664612  0.589415
# prio       0.001404  9.475989

# %%
cph_model.plot()
plt.show()

# %%
# Plot survival curves for different levels of the 'fin' variable
cph_model.plot_partial_effects_on_outcome('race', values=[0, 1])
# Out:
# <Axes: >

# %%
from lifelines import KaplanMeierFitter
import numpy as np
import pandas as pd

#Stratifying the dataset into age groups
df['age_group'] = pd.cut(df['age'], bins=[0, 18, 25, 35, 45, 55, 65, 75], right=False)

kmf = KaplanMeierFitter()

for group, df_group in df.groupby('age_group'):
    kmf.fit(df_group['week'], df_group['arrest'], )#label=str(group))
    kmf.plot()

# Customize the plot
plt.xlabel('Time (Weeks)')
plt.ylabel('Survival Probability')
plt.title('Survival Probabilities by Age Group')
plt.show()
# Out:
# /var/folders/zy/x4gc34qd36q0s944s4dk2n640000gn/T/ipykernel_97063/3216161412.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for group, df_group in df.groupby('age_group'):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/lifelines/utils/__init__.py:964, in pass_for_numeric_dtypes_or_raise_array(x)
#     963 if v.size == 0:
# --> 964     raise ValueError("Empty array/Series passed in.")
#     965 return v
#
# ValueError: Empty array/Series passed in.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 11
#       8 kmf = KaplanMeierFitter()
#      10 for group, df_group in df.groupby('age_group'):
# ---> 11     kmf.fit(df_group['week'], df_group['arrest'], )#label=str(group))
#      12     kmf.plot()
#      14 # Customize the plot
#
# File /opt/anaconda3/lib/python3.13/site-packages/lifelines/utils/__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      53 @wraps(function)
#      54 def f(model, *args, **kwargs):
#      55     cls.set_censoring_type(model, cls.RIGHT)
# ---> 56     return function(model, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/lifelines/fitters/kaplan_meier_fitter.py:127, in KaplanMeierFitter.fit(self, durations, event_observed, timeline, entry, label, alpha, ci_labels, weights, fit_options)
#      80 @CensoringType.right_censoring
#      81 def fit(
#      82     self,
#    (...)     91     fit_options=None,
#      92 ):  # pylint: disable=too-many-arguments,too-many-locals
#      93     """
#      94     Fit the model to a right-censored dataset
#      95
#    (...)    124
#     125     """
# --> 127     return self._fit(durations, event_observed, timeline, entry, label, alpha, ci_labels, weights)
#
# File /opt/anaconda3/lib/python3.13/site-packages/lifelines/fitters/kaplan_meier_fitter.py:361, in KaplanMeierFitter._fit(self, durations, event_observed, timeline, entry, label, alpha, ci_labels, weights)
#     351 primary_estimate_name = "survival_function_"
#     352 secondary_estimate_name = "cumulative_density_"
#     354 (
#     355     self.durations,
#     356     self.event_observed,
#     357     self.timeline,
#     358     self.entry,
#     359     self.event_table,
#     360     self.weights,
# --> 361 ) = _preprocess_inputs(durations, event_observed, timeline, entry, weights)
#     363 alpha = alpha if alpha else self.alpha
#     364 log_estimate, cumulative_sq_ = _additive_estimate(
#     365     self.event_table, self.timeline, self._additive_f, self._additive_var, is_left_censoring
#     366 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/lifelines/utils/__init__.py:904, in _preprocess_inputs(durations, event_observed, timeline, entry, weights)
#     899 """
#     900 Cleans and confirms input to what lifelines expects downstream
#     901 """
#     903 n = len(durations)
# --> 904 durations = np.asarray(pass_for_numeric_dtypes_or_raise_array(durations)).reshape((n,))
#     906 if weights is None:
#     907     weights = np.ones_like(durations)
#
# File /opt/anaconda3/lib/python3.13/site-packages/lifelines/utils/__init__.py:968, in pass_for_numeric_dtypes_or_raise_array(x)
#     965     return v
#     967 except:
# --> 968     raise ValueError("Values must be numeric: no strings, datetimes, objects, etc.")
#
# ValueError: Values must be numeric: no strings, datetimes, objects, etc.

# %%
#Predict the survival function for each observation
survival_functions = cph.predict_survival_function(X)


X2 = pd.DataFrame({
    'fin': [1, 0],
    'age': [35, 50],
    'race': [1, 1],
    'wexp': [0, 1],
    'mar': [0, 1],
    'paro': [1, 0],
    'prio': [3, 2]
})


#Plotting the survival function for the first individual/group in X
survival_functions.iloc[:, 0].plot()
plt.xlabel('Weeks Since Release')
plt.ylabel('Recidivism Probability')
plt.title('Predicted Survival Curve')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #Predict the survival function for each observation
# ----> 2 survival_functions = cph.predict_survival_function(X)
#       5 X2 = pd.DataFrame({
#       6     'fin': [1, 0],
#       7     'age': [35, 50],
#    (...)     12     'prio': [3, 2]
#      13 })
#      16 #Plotting the survival function for the first individual/group in X
#
# NameError: name 'cph' is not defined

# %%
X2 = pd.DataFrame({
    'fin': [1, 0],
    'age': [35, 50],
    'race': [1, 1],
    'wexp': [0, 1],
    'mar': [0, 1],
    'paro': [1, 0],
    'prio': [3, 2]
})

survival_functions = cph.predict_survival_function(X2)

#Plotting the survival function for individuals in X2
survival_functions.iloc[:, 0].plot()
survival_functions.iloc[:, 1].plot()

plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.title('Predicted Survival Curve')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       1 X2 = pd.DataFrame({
#       2     'fin': [1, 0],
#       3     'age': [35, 50],
#    (...)      8     'prio': [3, 2]
#       9 })
# ---> 11 survival_functions = cph.predict_survival_function(X2)
#      13 #Plotting the survival function for individuals in X2
#      14 survival_functions.iloc[:, 0].plot()
#
# NameError: name 'cph' is not defined

# %%
#Predict median survival times
median_survival_times = cph.predict_median(X)
median_survival_times 
#plt.hist(median_survival_times)

#Remove inf values for plotting
without_inf = median_survival_times[np.isfinite(median_survival_times)]
plt.hist(without_inf)
# Out:
# (array([ 1.,  0.,  0.,  0.,  2.,  2.,  1.,  2.,  5., 10.]),
#  array([20. , 23.2, 26.4, 29.6, 32.8, 36. , 39.2, 42.4, 45.6, 48.8, 52. ]),
#  <BarContainer object of 10 artists>)
