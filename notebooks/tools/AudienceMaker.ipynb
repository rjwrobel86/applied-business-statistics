# %%
#Input: VinSoluitons "SoldLogExport.csv"
#Output: Audience lists For Google Ads and Facebook Ads

import pandas as pd

df = pd.read_csv('/Users/robertwrobel/Downloads/SoldLogExport.csv')

df = df[['FirstName', 'LastName', 'PostalCode', 'Email', 'EmailAlt', 'DayPhone', 'EvePhone', 'CellPhone']]

df['Country'] = 'USA'

def convert_column_to_int(dataframe, column_name):
    dataframe[column_name] = pd.to_numeric(dataframe[column_name], errors='coerce').astype(pd.Int64Dtype())

convert_column_to_int(df, 'EvePhone')
convert_column_to_int(df, 'DayPhone')
convert_column_to_int(df, 'CellPhone')
convert_column_to_int(df, 'PostalCode')

def add_leading_one(dataframe, column_name):
    mask = dataframe[column_name].notna()
    dataframe.loc[mask, column_name] = '1' + dataframe.loc[mask, column_name].astype(str)

add_leading_one(df, 'EvePhone')
add_leading_one(df, 'DayPhone')
add_leading_one(df, 'CellPhone')


columns = {'FirstName':'First Name','LastName':'Last Name','PostalCode':'Zip','DayPhone':'Phone','EvePhone':'Phone','CellPhone':'Phone','EmailAlt':'Email'}
df = df.rename(columns=columns)

df.to_csv('/Users/robertwrobel/Downloads/google_audience.csv', index=False)

fb_columns = {'First Name':'fn', 'Last Name':'ln', 'Country':'country', 'Email':'email', 'Phone':'phone', 'Zip':'zip'}
df_fb = df.rename(columns=fb_columns)
df_fb['country'] = 'us'
df_fb.to_csv('/Users/robertwrobel/Downloads/fb_audience.csv', index=False)

# %%
#Input: VinSoluitons "SoldLogExport.csv"
#Output: Audience lists For Google Ads and Facebook Ads

import pandas as pd

df = pd.read_csv('/Users/robertwrobel/Downloads/Table_2126.csv')

df = df[['First Name', 'Last Name', 'Postal Code', 'Email', 'Alt Email', 'Daytime Phone', 'Evening Phone', 'Cell Phone']]

df['Country'] = 'USA'

def convert_column_to_int(dataframe, column_name):
    dataframe[column_name] = pd.to_numeric(dataframe[column_name], errors='coerce').astype(pd.Int64Dtype())

convert_column_to_int(df, 'Evening Phone')
convert_column_to_int(df, 'Daytime Phone')
convert_column_to_int(df, 'Cell Phone')
convert_column_to_int(df, 'Postal Code')

def add_leading_one(dataframe, column_name):
    mask = dataframe[column_name].notna()
    dataframe.loc[mask, column_name] = '1' + dataframe.loc[mask, column_name].astype(str)

add_leading_one(df, 'Evening Phone')
add_leading_one(df, 'Daytime Phone')
add_leading_one(df, 'Cell Phone')


columns = {'PostalCode':'Zip','Daytime Phone':'Phone','Evening Phone':'Phone','Cell Phone':'Phone','Alt Email':'Email'}
df = df.rename(columns=columns)

df = df.drop_duplicates()

df.to_csv('/Users/robertwrobel/Downloads/google_audience_leads.csv', index=False)

fb_columns = {'First Name':'fn', 'Last Name':'ln', 'Country':'country', 'Email':'email', 'Phone':'phone', 'Zip':'zip'}
df_fb = df.rename(columns=fb_columns)
df_fb['country'] = 'us'
df_fb.to_csv('/Users/robertwrobel/Downloads/fb_audience_leads.csv', index=False)
